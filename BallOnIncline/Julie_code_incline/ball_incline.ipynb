# %%
import os
print(os.getcwd())
os.chdir('/Users/juliemagnusson/Desktop/Project/BallOnIncline/Julie_code_incline')



# Ensure inline plotting
# %matplotlib inline

# Import the module and reload it
import importlib
import ball_incline

# Reload the module to ensure updates are reflected
importlib.reload(ball_incline)

# Import the updated class
from ball_incline import DistanceAnalyzer

# Use the updated class
analyzer = DistanceAnalyzer('../Ball_data/incline_distance.csv')
analyzer.load_data()
analyzer.calculate_relative_distances()
analyzer.perform_linear_fits()
analyzer.print_fit_results()
analyzer.plot_results()
# Out:
# /Users/juliemagnusson/Desktop/Project/BallOnIncline/Julie_code_incline
# Sensor 1 to Sensor 2:
#   Slope: 0.03000000000000043
#   Intercept: 11.276
#   Standard Error: 0.02457641145488931
# Sensor 2 to Sensor 3:
#   Slope: 0.020000000000000285
#   Intercept: 26.329999999999995
#   Standard Error: 0.01000000000000026
# Sensor 3 to Sensor 4:
#   Slope: -0.005000000000001137
#   Intercept: 41.242999999999995
#   Standard Error: 0.014640127503999165
# Sensor 4 to Sensor 5:
#   Slope: 0.025
#   Intercept: 56.94299999999999
#   Standard Error: 0.015524174696258353

# %%
from ball_incline import PeakAnalyzer

# Import the PeakAnalyzer class

# Create an instance of PeakAnalyzer
peak_analyzer = PeakAnalyzer('../Ball_data/BallIncline_1.csv')

# Load data and perform analysis
peak_analyzer.load_data()

peak_analyzer.plot_raw_data()
peak_analyzer.filter_data()
peak_analyzer.fit_step_functions()
peak_analyzer.plot_filtered_data_and_peaks()
peak_analyzer.get_peak_centers()
peak_analyzer.calculate_acceleration()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 16
#      14 peak_analyzer.plot_filtered_data_and_peaks()
#      15 peak_analyzer.get_peak_centers()
# ---> 16 peak_analyzer.calculate_acceleration()
#
# File ~/Desktop/Project/BallOnIncline/Julie_code_incline/ball_incline.py:145, in PeakAnalyzer.calculate_acceleration(self)
#     142 for i in range(len(mean_std_data) - 1):
#     143     # Calculate relative distance between consecutive sensors
#     144     distance = mean_std_data['Mean'][i + 1] - mean_std_data['Mean'][i]
# --> 145     time = time_intervals[i]  # Time interval between sensors
#     147     # Calculate acceleration using the formula: a = 2 * distance / time^2
#     148     acceleration = 2 * distance / (time ** 2)
#
# IndexError: index 4 is out of bounds for axis 0 with size 4

# %%
# !which python
# Out:
# /opt/anaconda3/envs/appstat25/bin/python

# %%
import ball_incline
print(ball_incline.__file__)
# Out:
# /Users/juliemagnusson/Desktop/Project/BallOnIncline/Julie_code_incline/ball_incline.py
